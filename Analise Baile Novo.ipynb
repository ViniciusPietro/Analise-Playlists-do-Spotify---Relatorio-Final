# %%
import pandas as pd

# %%
filename = "Baile Novo.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (90, 15)

# %%
df.describe()
# Out:
#           energy   liveness       tempo  speechiness  acousticness  \
# count  90.000000  90.000000   90.000000    90.000000     90.000000
# mean    0.667544   0.109058  126.586222     0.227959      0.299409
# std     0.170135   0.060433   29.572206     0.159302      0.207567
# min     0.196000   0.020100   65.637000     0.038600      0.003240
# 25%     0.550500   0.073925  100.450000     0.101250      0.103500
# 50%     0.679000   0.094200  132.541500     0.193500      0.280500
# 75%     0.789000   0.129750  150.054500     0.294000      0.417750
# max     0.995000   0.386000  179.988000     0.921000      0.824000
#
#        instrumentalness  time_signature  danceability        key  \
# count         90.000000       90.000000     90.000000  90.000000
# mean           0.018142        4.077778      0.785811   5.022222
# std            0.107059        0.429993      0.108456   3.499527
# min            0.000000        3.000000      0.544000   0.000000
# ...
