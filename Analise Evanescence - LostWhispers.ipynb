# %%
import pandas as pd

# %%
filename = "Evanescence-LostWhispers.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (12, 15)

# %%
df.describe()
# Out:
#           energy   liveness       tempo  speechiness  acousticness  \
# count  12.000000  12.000000   12.000000    12.000000     12.000000
# mean    0.605333   0.157258  129.261333     0.048892      0.374848
# std     0.290955   0.079171   40.678866     0.021175      0.392667
# min     0.186000   0.065400   76.619000     0.027900      0.000043
# 25%     0.324000   0.115250   96.043750     0.030900      0.000268
# 50%     0.628500   0.133000  119.568000     0.039200      0.319500
# 75%     0.874500   0.182000  171.279500     0.064725      0.694250
# max     0.954000   0.369000  179.968000     0.087100      0.971000
#
#        instrumentalness  time_signature  danceability        key  \
# count         12.000000       12.000000     12.000000  12.000000
# mean           0.048123        3.916667      0.379667   5.333333
# std            0.115332        0.288675      0.099398   3.256695
# min            0.000001        3.000000      0.255000   0.000000
# ...
