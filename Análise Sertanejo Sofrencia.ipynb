# %%
import pandas as pd

# %%
filename = "Sertanejo Sofrencia.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (60, 15)

# %%
df.describe()
# Out:
#           energy   liveness       tempo  speechiness  acousticness  \
# count  60.000000  60.000000   60.000000    60.000000     60.000000
# mean    0.770633   0.598152  125.478933     0.092250      0.440090
# std     0.126920   0.277301   23.223294     0.069431      0.215465
# min     0.487000   0.067000   77.048000     0.027200      0.042500
# 25%     0.695000   0.374500  110.625000     0.041700      0.274500
# 50%     0.806500   0.654000  120.442500     0.064800      0.466000
# 75%     0.870000   0.838500  142.585250     0.127500      0.610250
# max     0.953000   0.985000  176.212000     0.287000      0.892000
#
#        instrumentalness  time_signature  danceability        key  \
# count      6.000000e+01            60.0     60.000000  60.000000
# mean       5.600000e-07             4.0      0.629850   4.816667
# std        4.337741e-06             0.0      0.102324   3.797821
# min        0.000000e+00             4.0      0.374000   0.000000
# ...

# %%
## Analisando a playlist "Sertanejo Sofrência" as músicas popurlamente conhecidas como sofrências, não necessariamente são 
## tristes ou denotam alguma emoção triste. O valor de valência fica acima de 0.65, indicando que a harmonia entre instrumental
## ritmo e intensidade não são responsáveis pela sensação de sofrência, assim percebe-se que o fator responsável pela 
## sofrência está em fatores não analisados como letra, entonação de voz do cantor...
