# %%
import pandas as pd

# %%
filename = "Evanescence -SynthesisLive.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (16, 15)

# %%
df.describe()
# Out:
#           energy   liveness       tempo  speechiness  acousticness  \
# count  16.000000  16.000000   16.000000    16.000000     16.000000
# mean    0.545750   0.759188  115.758813     0.042275      0.508000
# std     0.187342   0.199298   32.896909     0.010926      0.275701
# min     0.189000   0.119000   76.200000     0.029600      0.076000
# 25%     0.433000   0.703500   92.388250     0.033300      0.333750
# 50%     0.577000   0.753000  104.470000     0.042700      0.463000
# 75%     0.660750   0.893750  137.946000     0.047625      0.693000
# max     0.837000   0.977000  188.031000     0.069500      0.947000
#
#        instrumentalness  time_signature  danceability        key  \
# count         16.000000       16.000000     16.000000  16.000000
# mean           0.000483        3.812500      0.279125   5.187500
# std            0.001041        0.403113      0.113235   3.525502
# min            0.000000        3.000000      0.148000   0.000000
# ...
