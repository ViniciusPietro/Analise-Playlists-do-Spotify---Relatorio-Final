# %%
import pandas as pd

# %%
filename = "Top 50 Brasil.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (50, 15)

# %%
df.describe()
# Out:
#          energy   liveness       tempo  speechiness  acousticness  \
# count  50.00000  50.000000   50.000000    50.000000     50.000000
# mean    0.73534   0.479932  130.085660     0.122984      0.316519
# std     0.13364   0.340660   28.729524     0.109111      0.219197
# min     0.34600   0.019700   76.471000     0.027800      0.001460
# 25%     0.67700   0.160250  110.813750     0.050675      0.117000
# 50%     0.73000   0.356500  128.488000     0.080150      0.325000
# 75%     0.83700   0.806500  149.126750     0.166750      0.476500
# max     0.94300   0.982000  195.620000     0.484000      0.860000
#
#        instrumentalness  time_signature  danceability        key  \
# count         50.000000        50.00000     50.000000  50.000000
# mean           0.000282         4.02000      0.673020   6.020000
# std            0.001540         0.24661      0.134066   3.909643
# min            0.000000         3.00000      0.390000   0.000000
# ...

# %%
##
