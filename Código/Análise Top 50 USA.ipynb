# %%
import pandas as pd

# %%
filename = "Top 50 USA.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (50, 15)

# %%
df.describe()
# Out:
#          energy   liveness       tempo  speechiness  acousticness  \
# count  50.00000  50.000000   50.000000    50.000000     50.000000
# mean    0.62242   0.210058  123.895860     0.144980      0.227846
# std     0.12886   0.167448   25.363664     0.115141      0.240997
# min     0.22500   0.067800   75.801000     0.031900      0.001460
# 25%     0.54800   0.101250  104.722750     0.056300      0.052575
# 50%     0.62100   0.135000  121.993500     0.099100      0.156000
# 75%     0.72000   0.279500  141.552750     0.198250      0.303750
# max     0.95500   0.790000  180.051000     0.481000      0.902000
#
#        instrumentalness  time_signature  danceability        key  \
# count         50.000000       50.000000     50.000000  50.000000
# mean           0.020464        3.940000      0.746240   6.200000
# std            0.102917        0.469911      0.128974   3.719776
# min            0.000000        1.000000      0.464000   0.000000
# ...

# %%
## Comparado com o top 50 Brasil, o top 50 USA, tem muito menos músicas ao vivo
