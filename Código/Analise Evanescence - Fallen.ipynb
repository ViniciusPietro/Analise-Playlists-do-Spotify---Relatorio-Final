# %%
import pandas as pd

# %%
filename = "Evanescence-Fallen.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (12, 15)

# %%
df.describe()
# Out:
#           energy   liveness       tempo  speechiness  acousticness  \
# count  12.000000  12.000000   12.000000    12.000000     12.000000
# mean    0.695083   0.197825  131.633083     0.048558      0.215933
# std     0.269106   0.088928   37.359820     0.019340      0.379900
# min     0.178000   0.086800   79.012000     0.030600      0.001350
# 25%     0.645250   0.106500   94.986250     0.032875      0.006370
# 50%     0.815500   0.217000  144.878500     0.044800      0.007680
# 75%     0.858750   0.251250  160.523250     0.056300      0.199775
# max     0.943000   0.342000  176.201000     0.093800      0.912000
#
#        instrumentalness  time_signature  danceability        key  \
# count         12.000000            12.0     12.000000  12.000000
# mean           0.001582             4.0      0.353167   6.250000
# std            0.003239             0.0      0.084538   3.360871
# min            0.000000             4.0      0.190000   2.000000
# ...
