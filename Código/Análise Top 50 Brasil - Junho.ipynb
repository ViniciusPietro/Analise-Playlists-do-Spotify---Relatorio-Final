# %%
import pandas as pd

# %%
filename = "Top 50 Brasil - Junho.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (50, 15)

# %%
df.describe()
# Out:
#           energy   liveness      tempo  speechiness  acousticness  \
# count  50.000000  50.000000   50.00000    50.000000     50.000000
# mean    0.709380   0.440924  129.86516     0.107328      0.336573
# std     0.142891   0.343826   28.96338     0.095796      0.243494
# min     0.346000   0.054500   76.80500     0.027800      0.001460
# 25%     0.610250   0.116500  110.81375     0.047950      0.117000
# 50%     0.721500   0.333000  130.78800     0.063800      0.311500
# 75%     0.823250   0.799750  146.03200     0.123250      0.508250
# max     0.943000   0.982000  195.62000     0.409000      0.860000
#
#        instrumentalness  time_signature  danceability        key  \
# count         50.000000        50.00000     50.000000  50.000000
# mean           0.000644         4.02000      0.649300   5.620000
# std            0.003027         0.24661      0.141903   4.004538
# min            0.000000         3.00000      0.339000   0.000000
# ...

# %%
##
