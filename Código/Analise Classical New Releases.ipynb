# %%
import pandas as pd

# %%
filename = "Classical New Releases.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (41, 15)

# %%
df.describe()
# Out:
#           energy   liveness       tempo  speechiness  acousticness  \
# count  41.000000  41.000000   41.000000    41.000000     41.000000
# mean    0.138051   0.137798  105.944512     0.042346      0.910854
# std     0.099777   0.101565   31.751316     0.009690      0.154307
# min     0.002300   0.069600   62.213000     0.030400      0.328000
# 25%     0.074700   0.100000   76.968000     0.036000      0.937000
# 50%     0.130000   0.109000  100.993000     0.039700      0.973000
# 75%     0.189000   0.132000  129.789000     0.046100      0.989000
# max     0.501000   0.678000  176.921000     0.083700      0.995000
#
#        instrumentalness  time_signature  danceability        key  \
# count         41.000000       41.000000     41.000000  41.000000
# mean           0.676079        3.756098      0.299356   5.000000
# std            0.343862        0.699303      0.102889   3.507136
# min            0.000000        1.000000      0.087300   0.000000
# ...
