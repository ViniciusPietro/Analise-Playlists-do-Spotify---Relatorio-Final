# %%
import pandas as pd

# %%
filename = "Evanescence-Evanescence.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (12, 15)

# %%
df.describe()
# Out:
#           energy   liveness       tempo  speechiness  acousticness  \
# count  12.000000  12.000000   12.000000    12.000000     12.000000
# mean    0.856667   0.183858  121.175833     0.079542      0.034338
# std     0.164641   0.137272   26.777080     0.034690      0.099606
# min     0.456000   0.073000   81.042000     0.027400      0.000054
# 25%     0.897250   0.094375   95.920000     0.059250      0.000285
# 50%     0.909500   0.151000  122.661000     0.081700      0.000545
# 75%     0.936500   0.183000  136.480000     0.087325      0.004237
# max     0.970000   0.562000  161.853000     0.157000      0.347000
#
#        instrumentalness  time_signature  danceability        key  \
# count         12.000000            12.0     12.000000  12.000000
# mean           0.009701             4.0      0.408583   4.666667
# std            0.019563             0.0      0.103756   3.938928
# min            0.000000             4.0      0.227000   0.000000
# ...
