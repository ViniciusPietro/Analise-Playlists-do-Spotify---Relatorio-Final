# %%
import pandas as pd

# %%
filename = "Classical Essentials.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (140, 15)

# %%
df.describe()
# Out:
#            energy    liveness       tempo  speechiness  acousticness  \
# count  140.000000  140.000000  140.000000   140.000000    140.000000
# mean     0.115642    0.127488  101.419100     0.045135      0.911329
# std      0.101877    0.083336   30.141733     0.019301      0.142007
# min      0.002100    0.042300    0.000000     0.000000      0.145000
# 25%      0.036100    0.084700   77.679500     0.038675      0.898750
# 50%      0.085500    0.103000   95.077000     0.041950      0.959500
# 75%      0.162250    0.125250  125.583750     0.046425      0.984000
# max      0.419000    0.570000  179.447000     0.242000      0.996000
#
#        instrumentalness  time_signature  danceability         key  \
# count        140.000000      140.000000    140.000000  140.000000
# mean           0.724221        3.635714      0.258311    4.921429
# std            0.285030        0.788503      0.134289    3.487012
# min            0.000000        0.000000      0.000000    0.000000
# ...
