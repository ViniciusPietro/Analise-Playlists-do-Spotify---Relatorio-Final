# %%
import pandas as pd

# %%
filename = "For Game.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (131, 15)

# %%
df.describe()
# Out:
#            energy    liveness       tempo  speechiness  acousticness  \
# count  131.000000  131.000000  131.000000   131.000000    131.000000
# mean     0.762878    0.173173  126.268267     0.091010      0.126785
# std      0.138396    0.135490   28.721354     0.075016      0.173855
# min      0.274000    0.019700   49.452000     0.028300      0.000046
# 25%      0.679000    0.084100  102.459000     0.046150      0.008485
# 50%      0.784000    0.121000  127.624000     0.062300      0.041100
# 75%      0.858000    0.211000  144.354500     0.098550      0.207000
# max      0.984000    0.671000  190.109000     0.380000      0.747000
#
#        instrumentalness  time_signature  danceability         key  \
# count        131.000000      131.000000    131.000000  131.000000
# mean           0.013311        3.977099      0.642117    5.847328
# std            0.080073        0.230906      0.157528    3.617209
# min            0.000000        3.000000      0.099300    0.000000
# ...
