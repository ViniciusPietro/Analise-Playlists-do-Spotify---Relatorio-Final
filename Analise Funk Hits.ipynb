# %%
import pandas as pd

# %%
filename = "Funk Hits.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (50, 15)

# %%
df.describe()
# Out:
#           energy   liveness      tempo  speechiness  acousticness  \
# count  50.000000  50.000000   50.00000    50.000000     50.000000
# mean    0.685720   0.157506  136.98152     0.244444      0.345962
# std     0.184771   0.119663   27.54022     0.182155      0.232232
# min     0.305000   0.019700   79.97500     0.030600      0.026500
# 25%     0.555000   0.081350  122.43400     0.098800      0.143750
# 50%     0.684500   0.108500  147.95100     0.186500      0.306000
# 75%     0.840750   0.184250  153.03150     0.359750      0.526500
# max     0.967000   0.669000  185.18600     0.841000      0.860000
#
#        instrumentalness  time_signature  danceability       key  \
# count         50.000000       50.000000     50.000000  50.00000
# mean           0.016897        4.020000      0.778140   5.84000
# std            0.118492        0.377424      0.094402   3.30343
# min            0.000000        3.000000      0.558000   0.00000
# ...
