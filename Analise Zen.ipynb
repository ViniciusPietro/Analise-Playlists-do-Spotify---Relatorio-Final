# %%
import pandas as pd

# %%
filename = "Zen.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (88, 15)

# %%
df.describe()
# Out:
#           energy   liveness       tempo  speechiness  acousticness  \
# count  88.000000  88.000000   88.000000    88.000000     88.000000
# mean    0.475545   0.218906  119.636977     0.056559      0.501818
# std     0.167836   0.194164   29.351846     0.046876      0.297212
# min     0.139000   0.059700   75.708000     0.024000      0.013700
# 25%     0.373500   0.108750   92.007250     0.030650      0.218500
# 50%     0.478500   0.126500  120.361500     0.037950      0.573000
# 75%     0.583250   0.229500  142.853250     0.063250      0.784500
# max     0.888000   0.886000  186.581000     0.290000      0.911000
#
#        instrumentalness  time_signature  danceability        key  \
# count         88.000000       88.000000     88.000000  88.000000
# mean           0.000314        3.954545      0.612307   4.954545
# std            0.001313        0.258603      0.118910   3.750583
# min            0.000000        3.000000      0.323000   0.000000
# ...
