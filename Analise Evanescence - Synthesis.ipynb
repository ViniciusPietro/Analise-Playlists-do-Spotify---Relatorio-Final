# %%
import pandas as pd

# %%
filename = "Evanescence-Synthesis.csv"
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (16, 15)

# %%
df.describe()
# Out:
#           energy   liveness       tempo  speechiness  acousticness  \
# count  16.000000  16.000000   16.000000    16.000000     16.000000
# mean    0.496656   0.170231  105.762687     0.041769      0.706000
# std     0.252608   0.133957   22.844123     0.010985      0.226739
# min     0.056000   0.071500   72.517000     0.030400      0.204000
# 25%     0.289250   0.106750   93.294750     0.034475      0.604250
# 50%     0.576000   0.112500   95.803000     0.037900      0.713000
# 75%     0.656500   0.160250  115.799500     0.046225      0.914500
# max     0.832000   0.514000  150.206000     0.064600      0.973000
#
#        instrumentalness  time_signature  danceability       key  \
# count         16.000000          16.000     16.000000  16.00000
# mean           0.159420           3.875      0.326937   5.50000
# std            0.343953           0.500      0.104837   2.94392
# min            0.000000           3.000      0.149000   0.00000
# ...
